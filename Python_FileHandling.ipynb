# %% [markdown]
# R -> Read ,
# w -> Write ,
# A -> Append

# %%
file=open("untitled.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# "Hello World!"
# we are students not cockroaches
# let's play

# %%
file=open("untitled.txt","r")
content=file.readline()
print(content)
# Out:
# "Hello World!"

# %%
file=open("untitled.txt","r")
content=file.readlines()
print(content)
# Out:
# ['"Hello World!"\n', 'we are students not cockroaches\n', "let's play\n"]

# %%
file=open("untitled_01","w")
file.write("Welcome,Kaise ho")
file.close()

# %%
file=open("untitled_01","a")
file.write("\nacha hun.")
file.close()
