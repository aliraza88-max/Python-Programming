# %% [markdown]
# ## Sets:-
# ### stores only unique values ,duplicate values automatically removed.
# ### unordered collection so elements don't have fixed positions and cannot be accesed using indexes

# %%
name={"Ali","Ahmed","Farooq"}

# %%
name
# Out:
# {'Ahmed', 'Ali', 'Farooq'}

# %%
type(name)
# Out:
# set

# %%
name_1={"ali","Ahmed","Mohsin"}

# %%
name.union(name_1)
# Out:
# {'Ahmed', 'Ali', 'Farooq', 'Mohsin', 'ali'}

# %%
name.intersection(name_1)
# Out:
# {'Ahmed'}

# %%
name.difference(name_1)
# Out:
# {'Ali', 'Farooq'}

# %% [markdown]
# # DICTIONARIES:-
# ### Dictionary Stores information in key value pairs..
# ### This is immutable data-structure..

# %%
data={"name":"Ali","Class":12}

# %%
data
# Out:
# {'name': 'Ali', 'Class': 12}

# %%
type(data)
# Out:
# dict

# %%
data["name"]="Ahmed"

# %%
data
# Out:
# {'name': 'Ahmed', 'Class': 12}

# %%
data.get("name")
# Out:
# 'Ahmed'

# %%
data.values()
# Out:
# dict_values(['Ahmed', 12])

# %%
data.keys()
# Out:
# dict_keys(['name', 'Class'])
