# %%
for i in range(5):
    print("Hello World")
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World

# %%
count=0
for i in range(5):
    count+=1
    print(count)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
while i <= 5:
    print(i)
    break
# Out:
# 4

# %%
for i in range(5,11):
    if i == 3:
        pass
    else:
        print("you can do it")
# Out:
# you can do it
# you can do it
# you can do it
# you can do it
# you can do it
# you can do it

# %%
for i in range(5,11):
    if i == 3:
        continue
    else:
        print("you can do it")
# Out:
# you can do it
# you can do it
# you can do it
# you can do it
# you can do it
# you can do it

# %%
for i in range(1,11):
    if i == 3:
        break
    else:
        print("try")
# Out:
# try
# try

# %%
j=int(input("Enter Your Number:"))

for i in range(1,11):
    print(j,"x",i,"=",i*j)
# Out:
# Enter Your Number: 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
j=1
z=int(input("enter your number:"))
# Out:
#   Cell In[12], line 4
#     print(j *= z)
#             ^
# SyntaxError: invalid syntax
